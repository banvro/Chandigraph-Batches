# %%
import pandas as pd

# %%
# pd=zim_test.csv

x = pd.read_csv("zim_test.csv")

# %%
x
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
x.sample(3)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 67        150    107       130     816.0
# 97         25    152       168     244.2
# 101        90     90       110     500.0

# %%
x.iloc[2:5,[2,3]]
# Out:
#    Maxpulse  Calories
# 2       135     340.0
# 3       175     282.4
# 4       148     406.0

# %%
x.loc[97]
# Out:
# Duration     25.0
# Pulse       152.0
# Maxpulse    168.0
# Calories    244.2
# Name: 97, dtype: float64

# %%
# dropna()

# %%
# 1) remove remove
# 2) add somthing at empty locations

# %%
x.head(20)
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        45     90       112       NaN
# 18        60    103       123     323.0
# 19        45     97       125     243.0

# %%
# fillna()

# %%
# dataset.fillna(filled_element)

# %%
q = x.fillna(120)

# %%
x.head(20)

# %%
q.head(20)
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        45     90       112     120.0
# 18        60    103       123     323.0
# 19        45     97       125     243.0

# %%
x[x.isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [Duration, Pulse, Maxpulse, Calories]
# Index: []

# %%
x.fillna(120, inplace = True)

# %%
x.head(20)
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        45     90       112     120.0
# 18        60    103       123     323.0
# 19        45     97       125     243.0

# %%
x["Duration"][0]
# Out:
# 60

# %%
x["Duration"][0] = 100
# Out:
# C:\Users\17nru\AppData\Local\Temp\ipykernel_15232\3683351311.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Duration"][0] = 100

# %%
x
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0         100    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
x["Duration"].fillna(50, inplace = True)

# %%
lst = []

for i in x.index:
    if x["Duration"][i] > 60:
        lst.append(i)

# %%
x.iloc[lst, :]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0         100    110       130     409.1
# 51         80    123       146     643.1
# 60        210    108       160    1376.0
# 61        160    110       137    1034.4
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 69        300    108       143    1500.2
# 70        150     97       129    1115.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 79        270    100       131    1729.0
# 83        120    100       130     500.0
# 87        120    100       157    1000.1
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 101        90     90       110     500.0
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# ...

# %%
for i in x.index:
    if x["Duration"][i] > 60:
        x["Duration"][i] = 50
# Out:
# C:\Users\17nru\AppData\Local\Temp\ipykernel_15232\2019596370.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Duration"][i] = 50
# C:\Users\17nru\AppData\Local\Temp\ipykernel_15232\2019596370.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Duration"][i] = 50
# C:\Users\17nru\AppData\Local\Temp\ipykernel_15232\2019596370.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Duration"][i] = 50
# ...

# %%
x
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          50    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        50    120       150     320.4
# 168        50    125       150     330.4
#
# [169 rows x 4 columns]

# %%
x
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          50    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        50    120       150     320.4
# 168        50    125       150     330.4
#
# [169 rows x 4 columns]

# %%
x["Duration"].mean()
# Out:
# 49.52662721893491

# %%
x.to_csv()
# Out:
# ',Duration,Pulse,Maxpulse,Calories\r\n0,50,110,130,409.1\r\n1,60,117,145,479.0\r\n2,60,103,135,340.0\r\n3,45,109,175,282.4\r\n4,45,117,148,406.0\r\n5,60,102,127,300.0\r\n6,60,110,136,374.0\r\n7,45,104,134,253.3\r\n8,30,109,133,195.1\r\n9,60,98,124,269.0\r\n10,60,103,147,329.3\r\n11,60,100,120,250.7\r\n12,60,106,128,345.3\r\n13,60,104,132,379.3\r\n14,60,98,123,275.0\r\n15,60,98,120,215.2\r\n16,60,100,120,300.0\r\n17,45,90,112,120.0\r\n18,60,103,123,323.0\r\n19,45,97,125,243.0\r\n20,60,108,131,364.2\r\n21,45,100,119,282.0\r\n22,60,130,101,300.0\r\n23,45,105,132,246.0\r\n24,60,102,126,334.5\r\n25,60,100,120,250.0\r\n26,60,92,118,241.0\r\n27,60,103,132,120.0\r\n28,60,100,132,280.0\r\n29,60,102,129,380.3\r\n30,60,92,115,243.0\r\n31,45,90,112,180.1\r\n32,60,101,124,299.0\r\n33,60,93,113,223.0\r\n34,60,107,136,361.0\r\n35,60,114,140,415.0\r\n36,60,102,127,300.0\r\n37,60,100,120,300.0\r\n38,60,100,120,300.0\r\n39,45,104,129,266.0\r\n40,45,90,112,180.1\r\n41,60,98,126,286.0\r\n42,60,100,122,3
# ...

# %%
x
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          50    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        50    120       150     320.4
# 168        50    125       150     330.4
#
# [169 rows x 4 columns]

# %%
x.drop(columns = ["Pulse", "Maxpulse"], inplace = True)

# %%
x
# Out:
#      Duration  Calories
# 0          60     409.1
# 1          60     479.0
# 2          60     340.0
# 3          45     282.4
# 4          45     406.0
# ..        ...       ...
# 164        60     290.8
# 165        60     300.0
# 166        60     310.2
# 167        75     320.4
# 168        75     330.4
#
# [169 rows x 2 columns]

# %%
# duplicate data

# %%
x
# Out:
#      Duration  Calories
# 0          60     409.1
# 1          60     479.0
# 2          60     340.0
# 3          45     282.4
# 4          45     406.0
# ..        ...       ...
# 164        60     290.8
# 165        60     300.0
# 166        60     310.2
# 167        75     320.4
# 168        75     330.4
#
# [169 rows x 2 columns]

# %%
df = pd.read_csv("zim_test.csv")

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# Length: 169, dtype: bool

# %%
df[df.duplicated()]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 36         60    102       127     300.0
# 37         60    100       120     300.0
# 38         60    100       120     300.0
# 40         45     90       112     180.1
# 71         60    109       153     387.6
# 113        45    100       120     225.3
# 155        60    111       151     368.5

# %%
# drop_

# %%
df.drop_duplicates(inplace = True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Duration, Pulse, Maxpulse, Calories]
# Index: []

# %%
df.shape
# Out:
# (162, 4)

# %%
df = pd.read_csv("zim_test.csv")

# %%
df[df.duplicated()]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 36         60    102       127     300.0
# 37         60    100       120     300.0
# 38         60    100       120     300.0
# 40         45     90       112     180.1
# 71         60    109       153     387.6
# 113        45    100       120     225.3
# 155        60    111       151     368.5

# %%
for i in df.index:
    if df["Duration"][i] == 60 and df["Pulse"][i] == 111 and df["Maxpulse"][i] == 151 and df["Calories"][i] == 368.5:
        print(i)
# Out:
# 124
# 155

# %%
df.loc[124]
# Out:
# Duration     60.0
# Pulse       111.0
# Maxpulse    151.0
# Calories    368.5
# Name: 124, dtype: float64

# %%
df.iloc[[124, 155], :]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 124        60    111       151     368.5
# 155        60    111       151     368.5
